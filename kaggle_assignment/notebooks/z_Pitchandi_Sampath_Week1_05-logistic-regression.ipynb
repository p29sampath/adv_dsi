# %% [markdown]
# # Training and Evaluate Model [Logistic Regression]

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from joblib import dump
from models import eval_model as evm
from models import eval_baseline as evb
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### Import Data Saved in Week1 Assignment

# %%
x_train = np.load('../data/processed/sp_x_train.npy')
y_train  = np.load('../data/processed/sp_y_train.npy' )

x_val = np.load('../data/processed/sp_x_val.npy')
y_val  = np.load('../data/processed/sp_y_val.npy' )

x_test = np.load('../data/processed/sp_x_test.npy')
y_test = np.load('../data/processed/sp_y_test.npy' )

x = np.load('../data/processed/sp_x.npy')
y = np.load('../data/processed/sp_y.npy' )


x_col_name = np.load('../data/processed/sp_x_col_name.npy')
y_col_name = np.load('../data/processed/sp_y_col_name.npy' )

# %% [markdown]
# #### Baseline test

# %%
evb.eval_baseline(x_train,y_train)
# Out:
# Accuracy Score:  0.8336916161813562  F1 Score  0.9093040605350101  Precision Score  0.8336916161813562  Recall Score  1.0 (BASELINE)

# %% [markdown]
# #### Logistic Regression with default Hyperparameter

# %%
evm.eval_model(LogisticRegression(random_state=0),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">True Positive</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">True Negative</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; fo
# ...

# %% [markdown]
# #### Using the CLASS_WEIGHT from the data

# %%
evm.eval_model(LogisticRegression(random_state=0,class_weight={0: 0.84, 1: 0.17}),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">True Positive</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">True Negative</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; fo
# ...

# %% [markdown]
# Clearly the Recall got hit. FP decreased but FN increased. So got better Precision but Recall got a hit.
#
# True Negative got a lot better

# %% [markdown]
# FN decrease compared to previous run. The Recall score is getting better

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from joblib import dump
from src.models import eval_model as evm
from src.models import eval_baseline as evb
# %load_ext autoreload
# %autoreload 2

# %%
x_train = np.load('../data/processed/sp_w2_x_train.npy')
y_train  = np.load('../data/processed/sp_w2_y_train.npy' )

x_val = np.load('../data/processed/sp_w2_x_val.npy')
y_val  = np.load('../data/processed/sp_w2_y_val.npy' )

x_test = np.load('../data/processed/sp_w2_x_test.npy')
y_test = np.load('../data/processed/sp_w2_y_test.npy' )

x = np.load('../data/processed/sp_w2_x.npy')
y = np.load('../data/processed/sp_w2_y.npy' )


x_col_name = np.load('../data/processed/sp_w2_x_col_name.npy')
y_col_name = np.load('../data/processed/sp_w2_y_col_name.npy' )

# %%
np.unique(y_train,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([4268,  852], dtype=int64))

# %%
evb.eval_baseline(x_train,y_train)
# Out:
# Accuracy Score:  0.83359375  F1 Score  0.0  Precision Score  0.0  Recall Score  0.0 (BASELINE)
# c:\users\xauspi\.virtualenvs\kaggle_assignment-dq2gjalz\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
evm.eval_model(RandomForestClassifier(random_state=8),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
cw = {1:.84,0:0.17}

# %%
evm.eval_model(RandomForestClassifier(random_state=8,class_weight=cw),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 50 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 150 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %% [markdown]
# #### With CLASS_WEIGHT

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250,class_weight=cw ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 150,class_weight=cw ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 50,class_weight=cw ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %% [markdown]
# #### Good with n_estimator=250

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, max_depth=2 ),x_train,y_train,x_val,y_val)
# Out:
# c:\users\xauspi\.virtualenvs\kaggle_assignment-dq2gjalz\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\xauspi\.virtualenvs\kaggle_assignment-dq2gjalz\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, max_depth=5 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, max_depth=15 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, max_depth=25 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, max_depth=35 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %% [markdown]
# #### Max Depth not Working

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, min_samples_leaf = 3 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, min_samples_leaf = 5 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, min_samples_leaf = 10 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, max_features  = 2 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, max_features  = 5 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,n_estimators= 250, max_features  = 10 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,max_features  = 10 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,max_features  = 15 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,max_depth  = 2 ),x_train,y_train,x_val,y_val)
# Out:
# c:\users\xauspi\.virtualenvs\kaggle_assignment-dq2gjalz\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\xauspi\.virtualenvs\kaggle_assignment-dq2gjalz\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,max_depth  = 4 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,max_depth  = 10 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,min_samples_leaf = 2 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,min_samples_leaf = 5 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
evm.eval_model(RandomForestClassifier(random_state=8,min_samples_leaf = 6 ),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...

# %%
from hyperopt import Trials, STATUS_OK, tpe, hp, fmin
from sklearn.metrics import accuracy_score, confusion_matrix,roc_curve, roc_auc_score, precision_score, recall_score, precision_recall_curve, f1_score, plot_confusion_matrix

# %%
space = {
    'max_depth': hp.choice('max_depth',range(3,200,1)),
    'max_features': hp.choice('max_features',range(1,15,1)),
    'min_samples_leaf': hp.choice('min_samples_leaf',range(1,14,1)),
    'n_estimators':  hp.choice('n_estimators',range(50,500,1))
}
space
# Out:
# {'max_depth': <hyperopt.pyll.base.Apply at 0x24240faab50>,
#  'max_features': <hyperopt.pyll.base.Apply at 0x24240fbb7c0>,
#  'min_samples_leaf': <hyperopt.pyll.base.Apply at 0x24240fbbb50>,
#  'n_estimators': <hyperopt.pyll.base.Apply at 0x24240fbbeb0>}

# %%
def objective(space):
   rf = RandomForestClassifier(
       max_depth = space['max_depth'],
       max_features = space['max_features'],
       min_samples_leaf = space['min_samples_leaf'],
       n_estimators = int(space['n_estimators'])
   ).fit(x_train,y_train)
   acc = recall_score(y_train, rf.predict(x_train))
   return{'loss': 1-acc, 'status': STATUS_OK }

best = fmin(
   fn=objective,  
   space=space,      
   algo=tpe.suggest,      
   max_evals=5
)
# Out:
# 100%|███████████████████████████████████████████████| 5/5 [00:12<00:00,  2.46s/trial, best loss: 0.0035211267605633756]

# %%
best
# Out:
# {'max_depth': 184,
#  'max_features': 12,
#  'min_samples_leaf': 0,
#  'n_estimators': 0}

# %%
evm.eval_model(RandomForestClassifier(random_state=8,max_depth=189,max_features=8,min_samples_leaf=1,n_estimators=199),x_train,y_train,x_val,y_val)
# Out:
# <div style="padding: 1rem; background: #2E3440; font-family: Ubuntu, 'Helvetica Neue', 'Segoe UI';"><div style="max-width: 100%; height: 2rem; display: flex;"><span style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem;"></span><div style="width: 100%; height: 2rem; display: flex; justify-content: space-evenly; padding: 0.25rem; text-align: center; font-weight: 700"><span style="width: 6rem; margin-top: 0.25em; color: #EBCB8B">AUROC</span><span style="width: 6rem; margin-top: 0.25em; color: #A3BE8C;">Accuracy</span><span style="width: 6rem; margin-top: 0.25em; color: #BF616A">F1</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Recall</span><span style="width: 6rem; margin-top: 0.25em; color: #B48EAD">Precision</span><span style="width: 6rem; margin-top: 0.25em; color: #D08770">R2</span></div></div><div style="max-width: 100%; height: 2rem; display: flex; margin-top: 0.5rem;"><div style="min-width: 5rem; margin-top: 0.5rem; margin-right: 1rem; font-weight: 
# ...
